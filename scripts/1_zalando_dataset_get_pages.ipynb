# %%
import os
import time
import re
import pickle
import zipfile
import shutil
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import time
from datetime import datetime

# %%
LOCAL_ROOT = './'
ITEMS_PATH = LOCAL_ROOT + 'data/items.pkl'
LOG_PATH = LOCAL_ROOT + 'log.txt'
FILE_CACHE_PATH = LOCAL_ROOT + 'data/pages.zip'
FILE_CACHE_ALGO = zipfile.ZIP_LZMA
CATEGORY_IDS = [
    'damenbekleidung-kleider',
    'damenbekleidung-shirts',
    'damenbekleidung-jeans',
    'damenbekleidung-jacken',
    'damenbekleidung-jacken-maentel',
    'damenbekleidung-blusen-tuniken',
]
PAGE_LIMIT = 140
DRIVER_PATH = '/Users/kofmanya/Desktop/HSE/My assignments/Diploma/Dataset/chromedriver'
ZALANDO_URL = 'https://www.zalando.ch'


def log(pattern: str, *args):
    msg = ('{} ' + pattern + '\n').format(datetime.now(), *args)
    print(msg, end='')
    with open(LOG_PATH, 'a', encoding='utf-8') as f:
        f.write(msg)


class Driver:
    def __init__(self):
        options = webdriver.ChromeOptions()
        service = Service(DRIVER_PATH)
        #self.driver = webdriver.Chrome(executable_path=DRIVER_PATH, options=options)
        self.driver = webdriver.Chrome(service=service, options=options)
        self.driver.execute_cdp_cmd('Network.enable', {})
        self.driver.execute_cdp_cmd('Network.setCookie', {'name': 'language-preference', 'value': 'en', 'domain': 'www.zalando.ch'})
        self.driver.execute_cdp_cmd('Network.disable', {})

    def __enter__(self):
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        self.driver.quit()

    def load_complete_page(self, url: str) -> str:
        self.driver.get(url)
        time.sleep(4)
        self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
        time.sleep(1)
        return self.driver.page_source


class FileRotator:
    def __init__(self, path: str, rotate_interval: float):
        self.path = path
        self.rotate_interval = rotate_interval
        self.last_rotate_ts = time.time()
        for suffix in ['.bak4', '.bak3', '.bak2', '.bak1', '']:
            if os.path.exists(self.path + suffix):
                self.copy_file(suffix, '.old')
                break

    def before_wrte(self):
        ts = time.time()
        if ts > self.last_rotate_ts + self.rotate_interval:
            log('[info] rotating {}', self.path)
            self.last_rotate_ts = ts
            self.move_file('.bak3', '.bak4')
            self.move_file('.bak2', '.bak3')
            self.move_file('.bak1', '.bak2')
            self.move_file('', '.bak1')
            self.copy_file('.bak1', '')

    def copy_file(self, src: str, dst: str):
        if os.path.exists(self.path + src):
            shutil.copy(self.path + src, self.path + dst)

    def move_file(self, src: str, dst: str):
        if os.path.exists(self.path + src):
            shutil.move(self.path + src, self.path + dst)


class FileCache:
    def __init__(self):
        self.rotator = FileRotator(FILE_CACHE_PATH, 300.0)
        try:
            log('[info] testing cache integrity')
            if os.path.exists(FILE_CACHE_PATH):
                with zipfile.ZipFile(FILE_CACHE_PATH, 'r', compression=FILE_CACHE_ALGO, compresslevel=9) as zipf:
                    bad_file = zipf.testzip()
                    if bad_file:
                        log('[error] bad file in cache: {}, please remove it', bad_file)
                    else:
                        log('[info] cache is ok')
            else:
                log('[info] cache does not exist')
        except:
            log('[error] failed to test cache integrity')

    def get(self, url: str) -> bytes:
        try:
            with zipfile.ZipFile(FILE_CACHE_PATH, 'r', compression=FILE_CACHE_ALGO, compresslevel=9) as zipf:
                with zipf.open(self.url_to_path(url), 'r') as f:
                    return f.read()
        except:
            return None

    def put(self, url: str, data: bytes):
        self.rotator.before_wrte()
        with zipfile.ZipFile(FILE_CACHE_PATH, 'a', compression=FILE_CACHE_ALGO, compresslevel=9) as zipf:
            with zipf.open(self.url_to_path(url), 'w') as f:
                f.write(data)

    def url_to_path(self, url: str) -> str:
        # drop prefix
        for prefix in ['http://', 'https://', 'www.']:
            if url.startswith(prefix):
                url = url[len(prefix):]
        # handle slashes
        url = url.replace('?', '/')
        while '//' in url:
            url = url.replace('//', '/')
        if url.endswith('/'):
            url = url[:-1]
        if url.startswith('/'):
            url = url[1:]
        if len(url) == 0:
            raise ValueError('empty url')
        # introduce / instead of 4th separator
        parts = url.split('/')
        for i in range(len(parts)):
            for sep in ['-', '_']:
                if parts[i].count(sep) >= 4:
                    groups = parts[i].split(sep, maxsplit=4)
                    parts[i] = sep.join(groups[:-1]) + '/' + groups[-1]
                    break
        return '/'.join(parts) + '.txt'


class Item:
    PRICE_CLEANUP_TOKENS = ['&nbsp;', 'From', 'CHF', '\u2019']
    PRICE_ATTRS = [
        'span class="voFjEy _4sa1cA m3OCL3 HlZ_Tf _65i7kZ"',
        'span class="voFjEy _4sa1cA m3OCL3 Yb63TQ ZiDB59 _65i7kZ"',
    ]

    def __init__(self, category_id: str, category_page: int, item_id: str, url: str, html: str):
        self.category = category_id
        self.category_page = category_page
        self.id = item_id
        self.url = url
        self.images = Item.find_images(html)
        self.brand = Item.find_brand(html)
        self.name = Item.find_name(html)
        self.price = Item.find_price(html)
        self.color = Item.find_color(html)
        self.material = Item.find_material(html)
        error, warning = self.check_fields()
        if error:
            self.error = error
            log('[error] {} - {}', url, error)
        elif warning:
            self.warning = warning
            log('[warning] {} - {}', url, warning)
        else:
            log('[debug] {} | {} | {} | {} | {} | {} | {} img(s)', self.url, self.brand, self.name, self.price, self.color, self.material, len(self.images))
            pass


    def find_images(html: str) -> list[str]:
        images1 = []
        for match in re.finditer('"Thumbnail Image ." src="(https://img01.ztat.net/article/[^"]+\.[a-zA-Z]{3,4})', html):
            images1.append(match.group(1))
        images2 = []
        for match in re.finditer(', Enlarge"( fetchpriority="[a-z]+")? src="(https://img01.ztat.net/article/[^"]+\.[a-zA-Z]{3,4})', html):
            images2.append(match.group(2))
        # merge 2 lists preserving order and removing duplicates
        res = []
        for i in range(max(len(images1), len(images2))):
            for x in [images1, images2]:
                if i < len(x) and (x[i] not in res):
                    res.append(x[i])
        return res

    def find_brand(html: str) -> str:
        return Item.find_attr(html, 'h5 class="voFjEy YZziZ- m3OCL3 HlZ_Tf q84f1m snL7ze"')
    
    def find_name(html: str) -> str:
        return Item.find_attr(html, 'span class="EKabf7 R_QwOV"')

    def find_price(html: str) -> str:
        for attr in Item.PRICE_ATTRS:
            prices = Item.find_attrs(html, attr, 2)
            for price in prices:
                price = Item.cleanup_price(price)
                if price:
                    return price
        return ''
    
    def cleanup_price(price: str) -> str:
        try:
            for token in Item.PRICE_CLEANUP_TOKENS:
                price = price.replace(token, '')
            price.strip()
            if price:
                return str(float(price))
        except:
            pass
        return ''            

    def find_color(html: str) -> str:
        return Item.find_attr(html, 'span class="voFjEy lystZ1 Sb5G3D HlZ_Tf zN9KaA"')

    def find_material(html: str) -> str:
        return Item.find_attr(html, 'dd class="voFjEy lystZ1 m3OCL3 HlZ_Tf zN9KaA" role="definition"')
    
    def find_attrs(html: str, attr: str, limit: int) -> list[str]:
        res = []
        start = 0
        for i in range(limit):
            start = html.find(attr + '>', start)
            if start < 0:
                break
            end = html.find('</', start + len(attr) + 1)
            if end < 0:
                break
            res.append(html[start + len(attr) + 1:end])
            start = end
        return res

    def find_attr(html: str, attr: str) -> str:
        start = html.find(attr + '>')
        if start >= 0:
            end = html.find('</', start + len(attr) + 1)
            if end >= 0:
                return html[start + len(attr) + 1:end]
        return ''

    def check_fields(self) -> tuple[str, str]:
        fields = self.__dict__
        for field in ['brand', 'name', 'price', 'color', 'material', 'images']:
            if not fields[field]:
                return ('no {}'.format(field), '')
        if len(self.images) > 0 and len(self.images) < 3:
            return ('', 'only {} image(s)'.format(len(self.images)))
        for image in self.images:
            dot = image.rfind('.')
            if dot >= 0 and (image[dot:].lower() != '.jpg'):
                return ('', 'non-jpg image {}'.format(image[dot:]))
        return ('', '')


class ItemScraper:
    def __init__(self, driver: Driver):
        self.driver = driver
        self.cache = FileCache()
        self.items_dict_rotator = FileRotator(ITEMS_PATH, 60)
        self.items_dict = dict()
        if os.path.exists(ITEMS_PATH):
            with open(ITEMS_PATH, 'rb') as f:
                self.items_dict = pickle.load(f)
 
    def __enter__(self):
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        self.save_items()

    def save_items(self):
        self.items_dict_rotator.before_wrte()
        with open(ITEMS_PATH, 'wb') as f:
            pickle.dump(self.items_dict, f)
        log('[info] dumped {} items', len(self.items_dict))

    def scrape_category(self, category_id: str):
        category_url = '{}/{}/'.format(ZALANDO_URL, category_id)
        item_ids = self.get_item_ids_in_category(category_url)
        for item_id, category_page in item_ids.items():
            if item_id in self.items_dict:
                continue
            item = self.load_item(category_id, category_page, item_id)
            self.items_dict[item_id] = item.__dict__
            if len(self.items_dict) % 100 == 0:
                self.save_items()
        self.save_items()

    def get_item_ids_in_category(self, category_url: str) -> dict[str, int]:
        item_ids = dict()
        num_pages = self.get_num_pages_in_category(category_url)
        log('[info] category {} has {} pages', category_url, num_pages)
        for i in range(1, min(num_pages, PAGE_LIMIT) + 1):
            url = '{}?p={}'.format(category_url, i)
            html = self.load_complete_page(url)
            on_page = set()
            for match in re.finditer('href="https://www.zalando.ch/([^"]+)\.html"', html):
                on_page.add(match.group(1))
            log_level = '[warning]' if len(on_page) < 60 else '[debug]'
            log('{} page {}?p={} has {} items', log_level, category_url, i, len(on_page))
            for item_id in on_page:
                item_ids[item_id] = i
        log('[info] category {} has {} items', category_url, len(item_ids))
        return item_ids

    def get_num_pages_in_category(self, category_url: str) -> int:
        html = self.load_complete_page(category_url)
        begin_pos = html.find('>Page 1 of ')
        end_pos = html.find('</span>', begin_pos)
        return int(html[begin_pos + 11:end_pos])

    def load_item(self, category_id: str, category_page: int, item_id: str) -> Item:
        url = '{}/{}.html'.format(ZALANDO_URL, item_id)
        html = self.load_complete_page(url)
        return Item(category_id, category_page, item_id, url, html)

    def load_complete_page(self, url: str) -> str:
        cached = self.cache.get(url)
        if cached:
            return cached.decode('utf-8')
        html = self.driver.load_complete_page(url)
        self.cache.put(url, html.encode('utf-8'))
        return html

# %%
with Driver() as driver:
    scrapper = ItemScraper(driver)
    for category_id in CATEGORY_IDS:
        scrapper.scrape_category(category_id)
# Out:
# 2024-12-19 23:37:08.018563 [info] testing cache integrity
# 2024-12-19 23:39:54.122986 [info] cache is ok
# 2024-12-19 23:39:54.438962 [info] category https://www.zalando.ch/damenbekleidung-kleider/ has 221 pages
# 2024-12-19 23:39:54.610278 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=1 has 99 items
# 2024-12-19 23:39:54.784030 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=2 has 99 items
# 2024-12-19 23:39:54.956812 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=3 has 99 items
# 2024-12-19 23:39:55.131727 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=4 has 114 items
# 2024-12-19 23:39:55.304852 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=5 has 84 items
# 2024-12-19 23:39:55.452171 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=6 has 99 items
# 2024-12-19 23:39:55.599503 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=7 has 99 items
# 2024-12-19 23:39:55.748301 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=8 has 99 items
# 2024-12-19 23:39:55.896517 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=9 has 84 items
# 2024-12-19 23:39:56.046957 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=10 has 114 items
# 2024-12-19 23:39:56.142523 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=11 has 84 items
# 2024-12-19 23:39:56.283911 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=12 has 99 items
# 2024-12-19 23:39:56.427275 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=13 has 99 items
# 2024-12-19 23:39:56.569766 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=14 has 99 items
# 2024-12-19 23:39:56.712943 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=15 has 99 items
# 2024-12-19 23:39:56.909569 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=16 has 84 items
# 2024-12-19 23:39:57.005875 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=17 has 114 items
# 2024-12-19 23:39:57.148016 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=18 has 84 items
# 2024-12-19 23:39:57.342139 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=19 has 99 items
# 2024-12-19 23:39:57.438397 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=20 has 99 items
# 2024-12-19 23:39:57.579971 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=21 has 99 items
# 2024-12-19 23:39:57.779614 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=22 has 114 items
# 2024-12-19 23:39:57.875976 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=23 has 114 items
# 2024-12-19 23:39:58.020399 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=24 has 114 items
# 2024-12-19 23:39:58.163822 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=25 has 99 items
# 2024-12-19 23:39:58.305553 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=26 has 114 items
# 2024-12-19 23:39:58.447137 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=27 has 114 items
# 2024-12-19 23:39:58.642574 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=28 has 114 items
# 2024-12-19 23:39:58.738420 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=29 has 111 items
# 2024-12-19 23:39:58.889162 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=30 has 99 items
# 2024-12-19 23:39:59.084222 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=31 has 111 items
# 2024-12-19 23:39:59.181103 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=32 has 114 items
# 2024-12-19 23:39:59.321101 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=33 has 84 items
# 2024-12-19 23:39:59.516937 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=34 has 111 items
# 2024-12-19 23:39:59.612403 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=35 has 114 items
# 2024-12-19 23:39:59.754311 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=36 has 96 items
# 2024-12-19 23:39:59.898067 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=37 has 99 items
# 2024-12-19 23:40:00.042677 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=38 has 114 items
# 2024-12-19 23:40:00.186078 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=39 has 99 items
# 2024-12-19 23:40:00.383228 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=40 has 114 items
# 2024-12-19 23:40:00.479183 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=41 has 99 items
# 2024-12-19 23:40:00.620996 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=42 has 99 items
# 2024-12-19 23:40:00.814629 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=43 has 84 items
# 2024-12-19 23:40:00.910750 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=44 has 96 items
# 2024-12-19 23:40:01.051106 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=45 has 96 items
# 2024-12-19 23:40:01.246016 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=46 has 96 items
# 2024-12-19 23:40:01.341565 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=47 has 96 items
# 2024-12-19 23:40:01.483376 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=48 has 96 items
# 2024-12-19 23:40:01.628396 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=49 has 96 items
# 2024-12-19 23:40:01.771878 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=50 has 96 items
# 2024-12-19 23:40:01.914231 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=51 has 96 items
# 2024-12-19 23:40:02.112313 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=52 has 111 items
# 2024-12-19 23:40:02.207970 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=53 has 96 items
# 2024-12-19 23:40:02.348935 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=54 has 111 items
# 2024-12-19 23:40:02.543287 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=55 has 96 items
# 2024-12-19 23:40:02.639660 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=56 has 96 items
# 2024-12-19 23:40:02.779771 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=57 has 96 items
# 2024-12-19 23:40:02.975283 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=58 has 96 items
# 2024-12-19 23:40:03.070826 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=59 has 96 items
# 2024-12-19 23:40:03.212125 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=60 has 96 items
# 2024-12-19 23:40:03.353708 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=61 has 96 items
# 2024-12-19 23:40:03.494704 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=62 has 111 items
# 2024-12-19 23:40:03.636938 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=63 has 111 items
# 2024-12-19 23:40:03.836125 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=64 has 99 items
# 2024-12-19 23:40:03.931388 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=65 has 111 items
# 2024-12-19 23:40:04.072168 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=66 has 111 items
# 2024-12-19 23:40:04.275480 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=67 has 111 items
# 2024-12-19 23:40:04.373194 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=68 has 111 items
# 2024-12-19 23:40:04.514263 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=69 has 111 items
# 2024-12-19 23:40:04.710544 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=70 has 111 items
# 2024-12-19 23:40:04.805680 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=71 has 99 items
# 2024-12-19 23:40:04.947931 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=72 has 84 items
# 2024-12-19 23:40:05.089419 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=73 has 84 items
# 2024-12-19 23:40:05.231302 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=74 has 99 items
# 2024-12-19 23:40:05.371418 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=75 has 84 items
# 2024-12-19 23:40:05.566954 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=76 has 99 items
# 2024-12-19 23:40:05.662746 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=77 has 99 items
# 2024-12-19 23:40:05.803947 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=78 has 99 items
# 2024-12-19 23:40:05.997545 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=79 has 84 items
# 2024-12-19 23:40:06.123589 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=80 has 99 items
# 2024-12-19 23:40:06.265964 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=81 has 84 items
# 2024-12-19 23:40:06.462466 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=82 has 99 items
# 2024-12-19 23:40:06.557866 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=83 has 98 items
# 2024-12-19 23:40:06.698875 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=84 has 99 items
# 2024-12-19 23:40:06.842416 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=85 has 99 items
# 2024-12-19 23:40:06.983843 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=86 has 99 items
# 2024-12-19 23:40:07.124786 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=87 has 99 items
# 2024-12-19 23:40:07.320410 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=88 has 99 items
# 2024-12-19 23:40:07.414696 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=89 has 84 items
# 2024-12-19 23:40:07.554861 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=90 has 99 items
# 2024-12-19 23:40:07.748397 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=91 has 97 items
# 2024-12-19 23:40:07.845103 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=92 has 97 items
# 2024-12-19 23:40:07.984696 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=93 has 97 items
# 2024-12-19 23:40:08.179581 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=94 has 99 items
# 2024-12-19 23:40:08.274202 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=95 has 97 items
# 2024-12-19 23:40:08.415079 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=96 has 84 items
# 2024-12-19 23:40:08.557693 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=97 has 99 items
# 2024-12-19 23:40:08.699559 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=98 has 99 items
# 2024-12-19 23:40:08.839641 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=99 has 99 items
# 2024-12-19 23:40:09.035330 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=100 has 99 items
# 2024-12-19 23:40:09.129597 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=101 has 99 items
# 2024-12-19 23:40:09.270209 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=102 has 98 items
# 2024-12-19 23:40:09.473627 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=103 has 99 items
# 2024-12-19 23:40:09.569925 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=104 has 99 items
# 2024-12-19 23:40:09.711030 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=105 has 98 items
# 2024-12-19 23:40:09.912002 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=106 has 99 items
# 2024-12-19 23:40:10.006493 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=107 has 99 items
# 2024-12-19 23:40:10.147470 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=108 has 99 items
# 2024-12-19 23:40:10.288526 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=109 has 99 items
# 2024-12-19 23:40:10.428846 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=110 has 99 items
# 2024-12-19 23:40:10.568358 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=111 has 99 items
# 2024-12-19 23:40:10.763626 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=112 has 99 items
# 2024-12-19 23:40:10.857915 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=113 has 99 items
# 2024-12-19 23:40:10.998814 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=114 has 99 items
# 2024-12-19 23:40:11.191103 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=115 has 99 items
# 2024-12-19 23:40:11.287111 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=116 has 99 items
# 2024-12-19 23:40:11.427111 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=117 has 99 items
# 2024-12-19 23:40:11.620358 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=118 has 99 items
# 2024-12-19 23:40:11.714740 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=119 has 99 items
# 2024-12-19 23:40:11.855109 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=120 has 99 items
# 2024-12-19 23:40:11.996059 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=121 has 99 items
# 2024-12-19 23:40:12.165441 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=122 has 99 items
# 2024-12-19 23:40:12.308010 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=123 has 99 items
# 2024-12-19 23:40:12.503598 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=124 has 99 items
# 2024-12-19 23:40:12.597672 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=125 has 99 items
# 2024-12-19 23:40:12.737923 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=126 has 99 items
# 2024-12-19 23:40:12.930813 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=127 has 99 items
# 2024-12-19 23:40:13.026563 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=128 has 99 items
# 2024-12-19 23:40:13.165975 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=129 has 99 items
# 2024-12-19 23:40:13.363046 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=130 has 99 items
# 2024-12-19 23:40:13.465185 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=131 has 96 items
# 2024-12-19 23:40:13.623510 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=132 has 96 items
# 2024-12-19 23:40:13.778704 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=133 has 99 items
# 2024-12-19 23:40:13.926187 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=134 has 99 items
# 2024-12-19 23:40:14.067051 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=135 has 96 items
# 2024-12-19 23:40:14.261322 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=136 has 99 items
# 2024-12-19 23:40:14.356617 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=137 has 99 items
# 2024-12-19 23:40:14.497993 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=138 has 99 items
# 2024-12-19 23:40:14.694702 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=139 has 99 items
# 2024-12-19 23:40:14.794073 [debug] page https://www.zalando.ch/damenbekleidung-kleider/?p=140 has 99 items
# 2024-12-19 23:40:14.794351 [info] category https://www.zalando.ch/damenbekleidung-kleider/ has 8253 items
# 2024-12-19 23:40:14.938603 [info] dumped 59866 items
# 2024-12-19 23:40:15.083439 [info] category https://www.zalando.ch/damenbekleidung-shirts/ has 356 pages
# 2024-12-19 23:40:15.276447 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=1 has 99 items
# 2024-12-19 23:40:15.374325 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=2 has 99 items
# 2024-12-19 23:40:15.515884 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=3 has 114 items
# 2024-12-19 23:40:15.660305 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=4 has 114 items
# 2024-12-19 23:40:15.803039 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=5 has 114 items
# 2024-12-19 23:40:15.947064 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=6 has 99 items
# 2024-12-19 23:40:16.141526 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=7 has 99 items
# 2024-12-19 23:40:16.238946 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=8 has 99 items
# 2024-12-19 23:40:16.380802 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=9 has 113 items
# 2024-12-19 23:40:16.577171 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=10 has 114 items
# 2024-12-19 23:40:16.673356 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=11 has 99 items
# 2024-12-19 23:40:16.818973 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=12 has 99 items
# 2024-12-19 23:40:17.014476 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=13 has 99 items
# 2024-12-19 23:40:17.111624 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=14 has 99 items
# 2024-12-19 23:40:17.253108 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=15 has 99 items
# 2024-12-19 23:40:17.396143 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=16 has 114 items
# 2024-12-19 23:40:17.537405 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=17 has 114 items
# 2024-12-19 23:40:17.706455 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=18 has 114 items
# 2024-12-19 23:40:17.903662 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=19 has 114 items
# 2024-12-19 23:40:18.001591 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=20 has 99 items
# 2024-12-19 23:40:18.142242 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=21 has 99 items
# 2024-12-19 23:40:18.337750 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=22 has 114 items
# 2024-12-19 23:40:18.432721 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=23 has 99 items
# 2024-12-19 23:40:18.573161 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=24 has 99 items
# 2024-12-19 23:40:18.765371 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=25 has 99 items
# 2024-12-19 23:40:18.862778 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=26 has 114 items
# 2024-12-19 23:40:19.004350 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=27 has 114 items
# 2024-12-19 23:40:19.146797 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=28 has 114 items
# 2024-12-19 23:40:19.287918 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=29 has 114 items
# 2024-12-19 23:40:19.430724 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=30 has 114 items
# 2024-12-19 23:40:19.627036 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=31 has 114 items
# 2024-12-19 23:40:19.724641 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=32 has 114 items
# 2024-12-19 23:40:19.866020 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=33 has 114 items
# 2024-12-19 23:40:20.072626 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=34 has 99 items
# 2024-12-19 23:40:20.169373 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=35 has 99 items
# 2024-12-19 23:40:20.311206 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=36 has 114 items
# 2024-12-19 23:40:20.504912 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=37 has 99 items
# 2024-12-19 23:40:20.602542 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=38 has 99 items
# 2024-12-19 23:40:20.744369 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=39 has 114 items
# 2024-12-19 23:40:20.889472 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=40 has 99 items
# 2024-12-19 23:40:21.032397 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=41 has 114 items
# 2024-12-19 23:40:21.176896 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=42 has 99 items
# 2024-12-19 23:40:21.370581 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=43 has 114 items
# 2024-12-19 23:40:21.468748 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=44 has 99 items
# 2024-12-19 23:40:21.610738 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=45 has 114 items
# 2024-12-19 23:40:21.808685 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=46 has 99 items
# 2024-12-19 23:40:21.905180 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=47 has 114 items
# 2024-12-19 23:40:22.049185 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=48 has 99 items
# 2024-12-19 23:40:22.244512 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=49 has 99 items
# 2024-12-19 23:40:22.370197 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=50 has 99 items
# 2024-12-19 23:40:22.512687 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=51 has 113 items
# 2024-12-19 23:40:22.659074 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=52 has 113 items
# 2024-12-19 23:40:22.802401 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=53 has 113 items
# 2024-12-19 23:40:22.946801 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=54 has 113 items
# 2024-12-19 23:40:23.140840 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=55 has 113 items
# 2024-12-19 23:40:23.238579 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=56 has 113 items
# 2024-12-19 23:40:23.379162 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=57 has 113 items
# 2024-12-19 23:40:23.574815 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=58 has 113 items
# 2024-12-19 23:40:23.670750 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=59 has 113 items
# 2024-12-19 23:40:23.813148 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=60 has 113 items
# 2024-12-19 23:40:24.007643 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=61 has 84 items
# 2024-12-19 23:40:24.104929 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=62 has 99 items
# 2024-12-19 23:40:24.246085 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=63 has 99 items
# 2024-12-19 23:40:24.387875 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=64 has 84 items
# 2024-12-19 23:40:24.528323 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=65 has 99 items
# 2024-12-19 23:40:24.671271 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=66 has 99 items
# 2024-12-19 23:40:24.864243 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=67 has 99 items
# 2024-12-19 23:40:24.960813 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=68 has 99 items
# 2024-12-19 23:40:25.101849 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=69 has 84 items
# 2024-12-19 23:40:25.302630 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=70 has 84 items
# 2024-12-19 23:40:25.399549 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=71 has 99 items
# 2024-12-19 23:40:25.540525 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=72 has 95 items
# 2024-12-19 23:40:25.733844 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=73 has 99 items
# 2024-12-19 23:40:25.831187 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=74 has 99 items
# 2024-12-19 23:40:25.972522 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=75 has 99 items
# 2024-12-19 23:40:26.114350 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=76 has 99 items
# 2024-12-19 23:40:26.254963 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=77 has 99 items
# 2024-12-19 23:40:26.397560 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=78 has 95 items
# 2024-12-19 23:40:26.591415 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=79 has 84 items
# 2024-12-19 23:40:26.716905 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=80 has 95 items
# 2024-12-19 23:40:26.858605 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=81 has 99 items
# 2024-12-19 23:40:27.054421 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=82 has 95 items
# 2024-12-19 23:40:27.150293 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=83 has 99 items
# 2024-12-19 23:40:27.291732 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=84 has 99 items
# 2024-12-19 23:40:27.485496 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=85 has 95 items
# 2024-12-19 23:40:27.582687 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=86 has 99 items
# 2024-12-19 23:40:27.722681 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=87 has 95 items
# 2024-12-19 23:40:27.864300 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=88 has 99 items
# 2024-12-19 23:40:28.005021 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=89 has 99 items
# 2024-12-19 23:40:28.146904 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=90 has 99 items
# 2024-12-19 23:40:28.339409 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=91 has 99 items
# 2024-12-19 23:40:28.435787 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=92 has 84 items
# 2024-12-19 23:40:28.576562 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=93 has 99 items
# 2024-12-19 23:40:28.772460 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=94 has 99 items
# 2024-12-19 23:40:28.867890 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=95 has 99 items
# 2024-12-19 23:40:29.009825 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=96 has 99 items
# 2024-12-19 23:40:29.203865 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=97 has 99 items
# 2024-12-19 23:40:29.300753 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=98 has 99 items
# 2024-12-19 23:40:29.440857 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=99 has 84 items
# 2024-12-19 23:40:29.581913 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=100 has 99 items
# 2024-12-19 23:40:29.722344 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=101 has 95 items
# 2024-12-19 23:40:29.864712 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=102 has 95 items
# 2024-12-19 23:40:30.057564 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=103 has 95 items
# 2024-12-19 23:40:30.154779 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=104 has 95 items
# 2024-12-19 23:40:30.295088 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=105 has 95 items
# 2024-12-19 23:40:30.490689 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=106 has 95 items
# 2024-12-19 23:40:30.592460 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=107 has 95 items
# 2024-12-19 23:40:30.733701 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=108 has 95 items
# 2024-12-19 23:40:30.953194 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=109 has 95 items
# 2024-12-19 23:40:31.049135 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=110 has 95 items
# 2024-12-19 23:40:31.190882 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=111 has 95 items
# 2024-12-19 23:40:31.332250 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=112 has 95 items
# 2024-12-19 23:40:31.473207 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=113 has 95 items
# 2024-12-19 23:40:31.613590 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=114 has 95 items
# 2024-12-19 23:40:31.808897 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=115 has 95 items
# 2024-12-19 23:40:31.904269 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=116 has 95 items
# 2024-12-19 23:40:32.045330 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=117 has 95 items
# 2024-12-19 23:40:32.238137 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=118 has 95 items
# 2024-12-19 23:40:32.334415 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=119 has 95 items
# 2024-12-19 23:40:32.474050 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=120 has 95 items
# 2024-12-19 23:40:32.669424 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=121 has 96 items
# 2024-12-19 23:40:32.764115 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=122 has 99 items
# 2024-12-19 23:40:32.905540 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=123 has 97 items
# 2024-12-19 23:40:33.047136 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=124 has 110 items
# 2024-12-19 23:40:33.188538 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=125 has 97 items
# 2024-12-19 23:40:33.328828 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=126 has 97 items
# 2024-12-19 23:40:33.524048 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=127 has 97 items
# 2024-12-19 23:40:33.618990 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=128 has 97 items
# 2024-12-19 23:40:33.759800 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=129 has 84 items
# 2024-12-19 23:40:33.955940 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=130 has 99 items
# 2024-12-19 23:40:34.052341 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=131 has 99 items
# 2024-12-19 23:40:34.191826 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=132 has 97 items
# 2024-12-19 23:40:34.385396 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=133 has 97 items
# 2024-12-19 23:40:34.479604 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=134 has 99 items
# 2024-12-19 23:40:34.620833 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=135 has 97 items
# 2024-12-19 23:40:34.762882 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=136 has 97 items
# 2024-12-19 23:40:34.932975 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=137 has 97 items
# 2024-12-19 23:40:35.078361 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=138 has 99 items
# 2024-12-19 23:40:35.273555 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=139 has 99 items
# 2024-12-19 23:40:35.368424 [debug] page https://www.zalando.ch/damenbekleidung-shirts/?p=140 has 97 items
# 2024-12-19 23:40:35.368583 [info] category https://www.zalando.ch/damenbekleidung-shirts/ has 9280 items
# 2024-12-19 23:40:35.491772 [info] dumped 59866 items
# 2024-12-19 23:40:35.634353 [info] category https://www.zalando.ch/damenbekleidung-jeans/ has 106 pages
# 2024-12-19 23:40:35.835627 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=1 has 110 items
# 2024-12-19 23:40:35.932281 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=2 has 114 items
# 2024-12-19 23:40:36.073561 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=3 has 99 items
# 2024-12-19 23:40:36.268556 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=4 has 110 items
# 2024-12-19 23:40:36.365971 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=5 has 84 items
# 2024-12-19 23:40:36.506980 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=6 has 99 items
# 2024-12-19 23:40:36.648854 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=7 has 99 items
# 2024-12-19 23:40:36.790073 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=8 has 99 items
# 2024-12-19 23:40:36.933576 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=9 has 110 items
# 2024-12-19 23:40:37.126891 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=10 has 110 items
# 2024-12-19 23:40:37.224422 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=11 has 99 items
# 2024-12-19 23:40:37.365800 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=12 has 113 items
# 2024-12-19 23:40:37.562330 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=13 has 110 items
# 2024-12-19 23:40:37.659168 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=14 has 99 items
# 2024-12-19 23:40:37.801349 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=15 has 114 items
# 2024-12-19 23:40:37.998034 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=16 has 95 items
# 2024-12-19 23:40:38.095610 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=17 has 110 items
# 2024-12-19 23:40:38.236418 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=18 has 99 items
# 2024-12-19 23:40:38.378243 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=19 has 114 items
# 2024-12-19 23:40:38.521405 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=20 has 110 items
# 2024-12-19 23:40:38.664190 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=21 has 114 items
# 2024-12-19 23:40:38.857139 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=22 has 99 items
# 2024-12-19 23:40:38.955398 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=23 has 114 items
# 2024-12-19 23:40:39.097215 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=24 has 114 items
# 2024-12-19 23:40:39.320749 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=25 has 114 items
# 2024-12-19 23:40:39.417348 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=26 has 114 items
# 2024-12-19 23:40:39.559046 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=27 has 114 items
# 2024-12-19 23:40:39.754248 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=28 has 99 items
# 2024-12-19 23:40:39.851487 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=29 has 99 items
# 2024-12-19 23:40:39.993600 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=30 has 99 items
# 2024-12-19 23:40:40.136216 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=31 has 114 items
# 2024-12-19 23:40:40.276789 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=32 has 99 items
# 2024-12-19 23:40:40.419613 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=33 has 99 items
# 2024-12-19 23:40:40.612887 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=34 has 114 items
# 2024-12-19 23:40:40.710181 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=35 has 114 items
# 2024-12-19 23:40:40.850815 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=36 has 114 items
# 2024-12-19 23:40:41.052609 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=37 has 114 items
# 2024-12-19 23:40:41.149958 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=38 has 114 items
# 2024-12-19 23:40:41.291384 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=39 has 114 items
# 2024-12-19 23:40:41.485323 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=40 has 114 items
# 2024-12-19 23:40:41.583613 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=41 has 112 items
# 2024-12-19 23:40:41.725160 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=42 has 109 items
# 2024-12-19 23:40:41.867755 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=43 has 112 items
# 2024-12-19 23:40:42.009918 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=44 has 112 items
# 2024-12-19 23:40:42.152829 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=45 has 112 items
# 2024-12-19 23:40:42.346161 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=46 has 112 items
# 2024-12-19 23:40:42.444238 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=47 has 108 items
# 2024-12-19 23:40:42.585583 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=48 has 112 items
# 2024-12-19 23:40:42.781830 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=49 has 112 items
# 2024-12-19 23:40:42.877436 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=50 has 111 items
# 2024-12-19 23:40:43.018489 [warning] page https://www.zalando.ch/damenbekleidung-jeans/?p=51 has 54 items
# 2024-12-19 23:40:43.213602 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=52 has 114 items
# 2024-12-19 23:40:43.311176 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=53 has 114 items
# 2024-12-19 23:40:43.452689 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=54 has 114 items
# 2024-12-19 23:40:43.595350 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=55 has 114 items
# 2024-12-19 23:40:43.736961 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=56 has 114 items
# 2024-12-19 23:40:43.882119 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=57 has 114 items
# 2024-12-19 23:40:44.076930 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=58 has 114 items
# 2024-12-19 23:40:44.203882 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=59 has 114 items
# 2024-12-19 23:40:44.346405 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=60 has 114 items
# 2024-12-19 23:40:44.542341 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=61 has 99 items
# 2024-12-19 23:40:44.637829 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=62 has 99 items
# 2024-12-19 23:40:44.778294 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=63 has 99 items
# 2024-12-19 23:40:44.973318 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=64 has 99 items
# 2024-12-19 23:40:45.070097 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=65 has 99 items
# 2024-12-19 23:40:45.212168 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=66 has 99 items
# 2024-12-19 23:40:45.353796 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=67 has 99 items
# 2024-12-19 23:40:45.495627 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=68 has 99 items
# 2024-12-19 23:40:45.638207 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=69 has 99 items
# 2024-12-19 23:40:45.830515 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=70 has 84 items
# 2024-12-19 23:40:45.928457 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=71 has 99 items
# 2024-12-19 23:40:46.068980 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=72 has 105 items
# 2024-12-19 23:40:46.270564 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=73 has 106 items
# 2024-12-19 23:40:46.366543 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=74 has 93 items
# 2024-12-19 23:40:46.508695 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=75 has 108 items
# 2024-12-19 23:40:46.704390 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=76 has 93 items
# 2024-12-19 23:40:46.802309 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=77 has 93 items
# 2024-12-19 23:40:46.943590 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=78 has 106 items
# 2024-12-19 23:40:47.085258 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=79 has 106 items
# 2024-12-19 23:40:47.225977 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=80 has 99 items
# 2024-12-19 23:40:47.368501 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=81 has 99 items
# 2024-12-19 23:40:47.562722 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=82 has 106 items
# 2024-12-19 23:40:47.661137 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=83 has 107 items
# 2024-12-19 23:40:47.802481 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=84 has 108 items
# 2024-12-19 23:40:47.999293 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=85 has 114 items
# 2024-12-19 23:40:48.095046 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=86 has 108 items
# 2024-12-19 23:40:48.236067 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=87 has 108 items
# 2024-12-19 23:40:48.430975 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=88 has 108 items
# 2024-12-19 23:40:48.527857 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=89 has 114 items
# 2024-12-19 23:40:48.668309 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=90 has 108 items
# 2024-12-19 23:40:48.810872 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=91 has 114 items
# 2024-12-19 23:40:48.952773 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=92 has 114 items
# 2024-12-19 23:40:49.094564 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=93 has 114 items
# 2024-12-19 23:40:49.288162 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=94 has 99 items
# 2024-12-19 23:40:49.414519 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=95 has 99 items
# 2024-12-19 23:40:49.556521 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=96 has 114 items
# 2024-12-19 23:40:49.752096 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=97 has 114 items
# 2024-12-19 23:40:49.847070 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=98 has 114 items
# 2024-12-19 23:40:49.988269 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=99 has 114 items
# 2024-12-19 23:40:50.183377 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=100 has 114 items
# 2024-12-19 23:40:50.280457 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=101 has 84 items
# 2024-12-19 23:40:50.420438 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=102 has 84 items
# 2024-12-19 23:40:50.562328 [debug] page https://www.zalando.ch/damenbekleidung-jeans/?p=103 has 84 items
# 2024-12-19 23:40:50.702144 [warning] page https://www.zalando.ch/damenbekleidung-jeans/?p=104 has 17 items
# 2024-12-19 23:40:50.843118 [warning] page https://www.zalando.ch/damenbekleidung-jeans/?p=105 has 17 items
# 2024-12-19 23:40:51.035715 [warning] page https://www.zalando.ch/damenbekleidung-jeans/?p=106 has 17 items
# 2024-12-19 23:40:51.035889 [info] category https://www.zalando.ch/damenbekleidung-jeans/ has 6350 items
# 2024-12-19 23:40:51.147254 [info] dumped 59866 items
# 2024-12-19 23:40:51.244086 [info] category https://www.zalando.ch/damenbekleidung-jacken/ has 179 pages
# 2024-12-19 23:40:51.385138 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=1 has 99 items
# 2024-12-19 23:40:51.589345 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=2 has 84 items
# 2024-12-19 23:40:51.687141 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=3 has 114 items
# 2024-12-19 23:40:51.828209 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=4 has 99 items
# 2024-12-19 23:40:52.025039 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=5 has 114 items
# 2024-12-19 23:40:52.121139 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=6 has 114 items
# 2024-12-19 23:40:52.263009 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=7 has 84 items
# 2024-12-19 23:40:52.405795 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=8 has 114 items
# 2024-12-19 23:40:52.548664 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=9 has 99 items
# 2024-12-19 23:40:52.690524 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=10 has 114 items
# 2024-12-19 23:40:52.887711 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=11 has 99 items
# 2024-12-19 23:40:52.983101 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=12 has 99 items
# 2024-12-19 23:40:53.127371 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=13 has 114 items
# 2024-12-19 23:40:53.321561 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=14 has 99 items
# 2024-12-19 23:40:53.418086 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=15 has 114 items
# 2024-12-19 23:40:53.558930 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=16 has 114 items
# 2024-12-19 23:40:53.756992 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=17 has 114 items
# 2024-12-19 23:40:53.853560 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=18 has 114 items
# 2024-12-19 23:40:53.995909 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=19 has 114 items
# 2024-12-19 23:40:54.138930 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=20 has 114 items
# 2024-12-19 23:40:54.281491 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=21 has 105 items
# 2024-12-19 23:40:54.423366 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=22 has 114 items
# 2024-12-19 23:40:54.621100 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=23 has 99 items
# 2024-12-19 23:40:54.716802 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=24 has 114 items
# 2024-12-19 23:40:54.858018 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=25 has 105 items
# 2024-12-19 23:40:55.082773 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=26 has 105 items
# 2024-12-19 23:40:55.179196 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=27 has 114 items
# 2024-12-19 23:40:55.321399 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=28 has 114 items
# 2024-12-19 23:40:55.514538 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=29 has 105 items
# 2024-12-19 23:40:55.611832 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=30 has 114 items
# 2024-12-19 23:40:55.753071 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=31 has 105 items
# 2024-12-19 23:40:55.895027 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=32 has 114 items
# 2024-12-19 23:40:56.036566 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=33 has 114 items
# 2024-12-19 23:40:56.179275 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=34 has 114 items
# 2024-12-19 23:40:56.373245 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=35 has 114 items
# 2024-12-19 23:40:56.469948 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=36 has 105 items
# 2024-12-19 23:40:56.611811 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=37 has 105 items
# 2024-12-19 23:40:56.816842 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=38 has 114 items
# 2024-12-19 23:40:56.912802 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=39 has 99 items
# 2024-12-19 23:40:57.054922 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=40 has 99 items
# 2024-12-19 23:40:57.248892 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=41 has 114 items
# 2024-12-19 23:40:57.345606 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=42 has 99 items
# 2024-12-19 23:40:57.486769 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=43 has 114 items
# 2024-12-19 23:40:57.628146 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=44 has 84 items
# 2024-12-19 23:40:57.768473 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=45 has 99 items
# 2024-12-19 23:40:57.909580 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=46 has 84 items
# 2024-12-19 23:40:58.102966 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=47 has 84 items
# 2024-12-19 23:40:58.198703 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=48 has 84 items
# 2024-12-19 23:40:58.338981 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=49 has 99 items
# 2024-12-19 23:40:58.533526 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=50 has 84 items
# 2024-12-19 23:40:58.628723 [warning] page https://www.zalando.ch/damenbekleidung-jacken/?p=51 has 54 items
# 2024-12-19 23:40:58.770145 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=52 has 114 items
# 2024-12-19 23:40:58.964009 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=53 has 99 items
# 2024-12-19 23:40:59.061132 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=54 has 114 items
# 2024-12-19 23:40:59.201741 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=55 has 114 items
# 2024-12-19 23:40:59.343462 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=56 has 114 items
# 2024-12-19 23:40:59.483828 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=57 has 114 items
# 2024-12-19 23:40:59.625348 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=58 has 114 items
# 2024-12-19 23:40:59.818321 [debug] page https://www.zalando.ch/damenbekleidung-jacken/?p=59 has 114 items
# ...
# 2024-12-19 23:47:14.207486 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=2 has 99 items
# 2024-12-19 23:47:14.311883 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=3 has 99 items
# 2024-12-19 23:47:14.463482 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=4 has 84 items
# 2024-12-19 23:47:14.708511 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=5 has 99 items
# 2024-12-19 23:47:14.816244 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=6 has 99 items
# 2024-12-19 23:47:14.968587 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=7 has 99 items
# 2024-12-19 23:47:15.121823 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=8 has 84 items
# 2024-12-19 23:47:15.273949 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=9 has 99 items
# 2024-12-19 23:47:15.424381 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=10 has 99 items
# 2024-12-19 23:47:15.634885 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=11 has 99 items
# 2024-12-19 23:47:15.761380 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=12 has 99 items
# 2024-12-19 23:47:15.936212 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=13 has 99 items
# 2024-12-19 23:47:16.151856 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=14 has 99 items
# 2024-12-19 23:47:16.259289 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=15 has 99 items
# 2024-12-19 23:47:16.408981 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=16 has 99 items
# 2024-12-19 23:47:16.613267 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=17 has 99 items
# 2024-12-19 23:47:16.718706 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=18 has 99 items
# 2024-12-19 23:47:16.868595 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=19 has 99 items
# 2024-12-19 23:47:17.022111 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=20 has 99 items
# 2024-12-19 23:47:17.174365 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=21 has 114 items
# 2024-12-19 23:47:17.328008 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=22 has 114 items
# 2024-12-19 23:47:17.535911 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=23 has 114 items
# 2024-12-19 23:47:17.642013 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=24 has 114 items
# 2024-12-19 23:47:17.793455 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=25 has 114 items
# 2024-12-19 23:47:18.000492 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=26 has 114 items
# 2024-12-19 23:47:18.106683 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=27 has 99 items
# 2024-12-19 23:47:18.257922 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=28 has 114 items
# 2024-12-19 23:47:18.465260 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=29 has 114 items
# 2024-12-19 23:47:18.572674 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=30 has 114 items
# 2024-12-19 23:47:18.725888 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=31 has 114 items
# 2024-12-19 23:47:18.879810 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=32 has 114 items
# 2024-12-19 23:47:19.032428 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=33 has 114 items
# 2024-12-19 23:47:19.185818 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=34 has 114 items
# 2024-12-19 23:47:19.395913 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=35 has 99 items
# 2024-12-19 23:47:19.500282 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=36 has 114 items
# 2024-12-19 23:47:19.651990 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=37 has 99 items
# 2024-12-19 23:47:19.893018 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=38 has 114 items
# 2024-12-19 23:47:20.007537 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=39 has 114 items
# 2024-12-19 23:47:20.161742 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=40 has 114 items
# 2024-12-19 23:47:20.368378 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=41 has 99 items
# 2024-12-19 23:47:20.474986 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=42 has 114 items
# 2024-12-19 23:47:20.627795 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=43 has 114 items
# 2024-12-19 23:47:20.780054 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=44 has 114 items
# 2024-12-19 23:47:20.932775 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=45 has 99 items
# 2024-12-19 23:47:21.085049 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=46 has 99 items
# 2024-12-19 23:47:21.286776 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=47 has 99 items
# 2024-12-19 23:47:21.392719 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=48 has 114 items
# 2024-12-19 23:47:21.543894 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=49 has 99 items
# 2024-12-19 23:47:21.747060 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=50 has 99 items
# 2024-12-19 23:47:21.850457 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=51 has 114 items
# 2024-12-19 23:47:21.998160 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=52 has 114 items
# 2024-12-19 23:47:22.203185 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=53 has 114 items
# 2024-12-19 23:47:22.307482 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=54 has 114 items
# 2024-12-19 23:47:22.456055 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=55 has 114 items
# 2024-12-19 23:47:22.605915 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=56 has 114 items
# 2024-12-19 23:47:22.756512 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=57 has 114 items
# 2024-12-19 23:47:22.905308 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=58 has 114 items
# 2024-12-19 23:47:23.106464 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=59 has 114 items
# 2024-12-19 23:47:23.210196 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=60 has 114 items
# 2024-12-19 23:47:23.358373 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=61 has 97 items
# 2024-12-19 23:47:23.589941 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=62 has 97 items
# 2024-12-19 23:47:23.692224 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=63 has 97 items
# 2024-12-19 23:47:23.850021 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=64 has 97 items
# 2024-12-19 23:47:24.054400 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=65 has 97 items
# 2024-12-19 23:47:24.158745 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=66 has 97 items
# 2024-12-19 23:47:24.306659 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=67 has 97 items
# 2024-12-19 23:47:24.463359 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=68 has 96 items
# 2024-12-19 23:47:24.613661 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=69 has 97 items
# 2024-12-19 23:47:24.763424 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=70 has 97 items
# 2024-12-19 23:47:24.963701 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=71 has 99 items
# 2024-12-19 23:47:25.068043 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=72 has 99 items
# 2024-12-19 23:47:25.222860 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=73 has 99 items
# 2024-12-19 23:47:25.428488 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=74 has 114 items
# 2024-12-19 23:47:25.532509 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=75 has 114 items
# 2024-12-19 23:47:25.681982 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=76 has 99 items
# 2024-12-19 23:47:25.886753 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=77 has 99 items
# 2024-12-19 23:47:25.990139 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=78 has 99 items
# 2024-12-19 23:47:26.138695 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=79 has 99 items
# 2024-12-19 23:47:26.287537 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=80 has 99 items
# 2024-12-19 23:47:26.437207 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=81 has 99 items
# 2024-12-19 23:47:26.586913 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=82 has 99 items
# 2024-12-19 23:47:26.787868 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=83 has 99 items
# 2024-12-19 23:47:26.891913 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=84 has 99 items
# 2024-12-19 23:47:27.039886 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=85 has 99 items
# 2024-12-19 23:47:27.242178 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=86 has 99 items
# 2024-12-19 23:47:27.344321 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=87 has 99 items
# 2024-12-19 23:47:27.492542 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=88 has 99 items
# 2024-12-19 23:47:27.724630 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=89 has 99 items
# 2024-12-19 23:47:27.831469 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=90 has 99 items
# 2024-12-19 23:47:27.979497 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=91 has 99 items
# 2024-12-19 23:47:28.131717 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=92 has 99 items
# 2024-12-19 23:47:28.280621 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=93 has 99 items
# 2024-12-19 23:47:28.430011 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=94 has 99 items
# 2024-12-19 23:47:28.632691 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=95 has 84 items
# 2024-12-19 23:47:28.734769 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=96 has 96 items
# 2024-12-19 23:47:28.882597 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=97 has 99 items
# 2024-12-19 23:47:29.084764 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=98 has 97 items
# 2024-12-19 23:47:29.188606 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=99 has 99 items
# 2024-12-19 23:47:29.336678 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=100 has 99 items
# 2024-12-19 23:47:29.538172 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=101 has 99 items
# 2024-12-19 23:47:29.640346 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=102 has 99 items
# 2024-12-19 23:47:29.788722 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=103 has 99 items
# 2024-12-19 23:47:29.938324 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=104 has 99 items
# 2024-12-19 23:47:30.087196 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=105 has 99 items
# 2024-12-19 23:47:30.234464 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=106 has 99 items
# 2024-12-19 23:47:30.443318 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=107 has 99 items
# 2024-12-19 23:47:30.546956 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=108 has 99 items
# 2024-12-19 23:47:30.695038 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=109 has 99 items
# 2024-12-19 23:47:30.896431 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=110 has 99 items
# 2024-12-19 23:47:31.000199 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=111 has 99 items
# 2024-12-19 23:47:31.147792 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=112 has 99 items
# 2024-12-19 23:47:31.378934 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=113 has 99 items
# 2024-12-19 23:47:31.481939 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=114 has 99 items
# 2024-12-19 23:47:31.629735 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=115 has 99 items
# 2024-12-19 23:47:31.780060 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=116 has 99 items
# 2024-12-19 23:47:31.929050 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=117 has 99 items
# 2024-12-19 23:47:32.076812 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=118 has 99 items
# 2024-12-19 23:47:32.280078 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=119 has 99 items
# 2024-12-19 23:47:32.382947 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=120 has 99 items
# 2024-12-19 23:47:32.531830 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=121 has 99 items
# 2024-12-19 23:47:32.733140 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=122 has 99 items
# 2024-12-19 23:47:32.836928 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=123 has 99 items
# 2024-12-19 23:47:32.984350 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=124 has 99 items
# 2024-12-19 23:47:33.185805 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=125 has 99 items
# 2024-12-19 23:47:33.286816 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=126 has 99 items
# 2024-12-19 23:47:33.435653 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=127 has 99 items
# 2024-12-19 23:47:33.584609 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=128 has 99 items
# 2024-12-19 23:47:33.732964 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=129 has 99 items
# 2024-12-19 23:47:33.881260 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=130 has 99 items
# 2024-12-19 23:47:34.084536 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=131 has 99 items
# 2024-12-19 23:47:34.185986 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=132 has 99 items
# 2024-12-19 23:47:34.333882 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=133 has 99 items
# 2024-12-19 23:47:34.536975 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=134 has 99 items
# 2024-12-19 23:47:34.640422 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=135 has 99 items
# 2024-12-19 23:47:34.787680 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=136 has 99 items
# 2024-12-19 23:47:35.018350 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=137 has 99 items
# 2024-12-19 23:47:35.127156 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=138 has 84 items
# 2024-12-19 23:47:35.277855 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=139 has 99 items
# 2024-12-19 23:47:35.427664 [debug] page https://www.zalando.ch/damenbekleidung-blusen-tuniken/?p=140 has 99 items
# 2024-12-19 23:47:35.427846 [info] category https://www.zalando.ch/damenbekleidung-blusen-tuniken/ has 8188 items
# 2024-12-19 23:47:35.540438 [info] dumped 59913 items
